# %%
import pandas as pd
import numpy as np

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
df = pd.read_excel(r"C:\Users\ABC\Desktop\resume builder/database/Graphura_Cleaned_Resume_CV_data (sachin).xlsx")

print("Dataset Loaded Successfully")
# Out:
# Dataset Loaded Successfully

# %%
df.head()
# Out:
#    Sr No.                       Name        Applied_Role  \
# 0       1                 Ajit Kumar  Back-end Developer
# 1       2  Akansha Manohar Pendorkar  Back-end Developer
# 2       3                Akash Patil  Back-end Developer
# 3       4          Anchal Kasettiwar  Back-end Developer
# 4       5              Aneeka Sharma  Back-end Developer
#
#                           Email Education     Experience  \
# 0           ajit62062@gmail.com     B.COM        Fresher
# 1  akanshapendorkar96@gmail.com      B.SC  No Experience
# 2     aakashpatil7140@gmail.com     B.COM       3 Months
# 3    kasettiwaranchal@gmail.com    B.TECH       6 Months
# 4     aneekasharma767@gmail.com    B.TECH        Fresher
#
#                                             projects  \
# 0  Global Sales Dashboard (Power BI), Note Taker ...
# 1  Student Mental Health Dashboard (Excel), SQL C...
# 2  Voice-Controlled Email System (Python), E-Lear...
# 3                                 None (skills only)
# ...

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 271
# Columns : 9

# %%
print(df.columns.tolist())
# Out:
# ['Sr No.', 'Name', 'Applied_Role', 'Email', 'Education', 'Experience', 'projects', 'Skills', 'Certificates']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sr No.        271 non-null    int64
#  1   Name          271 non-null    object
#  2   Applied_Role  271 non-null    object
#  3   Email         271 non-null    object
#  4   Education     271 non-null    object
#  5   Experience    271 non-null    object
#  6   projects      212 non-null    object
#  7   Skills        261 non-null    object
#  8   Certificates  194 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 19.2+ KB

# %%
df.isnull().sum()
# Out:
# Sr No.           0
# Name             0
# Applied_Role     0
# Email            0
# Education        0
# Experience       0
# projects        59
# Skills          10
# Certificates    77
# dtype: int64

# %%
print("Duplicate Rows :", df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %%
df = df.drop_duplicates()

print("Duplicates Removed")
# Out:
# Duplicates Removed

# %%
df["Education"] = df["Education"].fillna("")
df["Experience"] = df["Experience"].fillna("")
df["projects"] = df["projects"].fillna("")
df["Skills"] = df["Skills"].fillna("")
df["Certificates"] = df["Certificates"].fillna("")

print("Missing Values Filled")
# Out:
# Missing Values Filled

# %%
df["Resume_Text"] = (
    df["Education"] + " " +
    df["Experience"] + " " +
    df["projects"] + " " +
    df["Skills"] + " " +
    df["Certificates"]
)

# %%
df[["Applied_Role", "Resume_Text"]].head()
# Out:
#          Applied_Role                                        Resume_Text
# 0  Back-end Developer  B.COM Fresher Global Sales Dashboard (Power BI...
# 1  Back-end Developer  B.SC No Experience Student Mental Health Dashb...
# 2  Back-end Developer  B.COM 3 Months Voice-Controlled Email System (...
# 3  Back-end Developer  B.TECH 6 Months None (skills only) MS Excel, W...
# 4  Back-end Developer  B.TECH Fresher Rice Recommendation (Random For...

# %%
df.to_csv("processed_resume_dataset.csv", index=False)

print("Processed Dataset Saved Successfully")
# Out:
# Processed Dataset Saved Successfully
