# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

import matplotlib.pyplot as plt

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
import pickle

# Load Training Data
with open("../models/X_train.pkl", "rb") as file:
    X_train = pickle.load(file)

with open("../models/X_test.pkl", "rb") as file:
    X_test = pickle.load(file)

with open("../models/y_train.pkl", "rb") as file:
    y_train = pickle.load(file)

with open("../models/y_test.pkl", "rb") as file:
    y_test = pickle.load(file)

print("Training Data Loaded Successfully")
print("X_train Shape :", X_train.shape)
print("X_test Shape  :", X_test.shape)
print("y_train Shape :", y_train.shape)
print("y_test Shape  :", y_test.shape)
# Out:
# Training Data Loaded Successfully
# X_train Shape : (216, 5261)
# X_test Shape  : (55, 5261)
# y_train Shape : (216,)
# y_test Shape  : (55,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr_model = LogisticRegression(
    max_iter=5000,
    random_state=42
)

lr_model.fit(X_train, y_train)

lr_pred = lr_model.predict(X_test)

lr_accuracy = accuracy_score(y_test, lr_pred)

print("Logistic Regression Accuracy:", round(lr_accuracy*100,2), "%")
# Out:
# Logistic Regression Accuracy: 49.09 %

# %%
nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)

nb_accuracy = accuracy_score(y_test, nb_pred)

print("Naive Bayes Accuracy:",
      round(nb_accuracy * 100, 2), "%")
# Out:
# Naive Bayes Accuracy: 38.18 %

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt_model = DecisionTreeClassifier(
    random_state=42
)

dt_model.fit(X_train, y_train)

dt_pred = dt_model.predict(X_test)

dt_accuracy = accuracy_score(y_test, dt_pred)

print("Decision Tree Accuracy:", round(dt_accuracy*100,2), "%")
# Out:
# Decision Tree Accuracy: 56.36 %

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight="balanced"
)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy:", round(rf_accuracy*100,2), "%")
# Out:
# Random Forest Accuracy: 54.55 %

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

svm_model = LinearSVC(
    C=2.0,
    class_weight="balanced",
    max_iter=10000,
    random_state=42
)

svm_model.fit(X_train, y_train)

svm_pred = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, svm_pred)

print("SVM Accuracy:", round(svm_accuracy*100,2), "%")
# Out:
# SVM Accuracy: 69.09 %

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

svm_model = LinearSVC(
    C=2,
    class_weight="balanced",
    max_iter=10000,
    random_state=42
)

svm_model.fit(X_train, y_train)

svm_pred = svm_model.predict(X_test)

svm_accuracy = accuracy_score(y_test, svm_pred)

print("Linear SVM Accuracy:", round(svm_accuracy*100,2), "%")
# Out:
# Linear SVM Accuracy: 69.09 %

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)

nb_pred = nb_model.predict(X_test)

nb_accuracy = accuracy_score(y_test, nb_pred)

print("Naive Bayes Accuracy:", round(nb_accuracy*100,2), "%")
# Out:
# Naive Bayes Accuracy: 38.18 %

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn_model = KNeighborsClassifier(n_neighbors=5)

knn_model.fit(X_train, y_train)

knn_pred = knn_model.predict(X_test)

knn_accuracy = accuracy_score(y_test, knn_pred)

print("KNN Accuracy:", round(knn_accuracy*100,2), "%")
# Out:
# KNN Accuracy: 60.0 %

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

dt_model = DecisionTreeClassifier(
    random_state=42
)

dt_model.fit(X_train, y_train)

dt_pred = dt_model.predict(X_test)

dt_accuracy = accuracy_score(y_test, dt_pred)

print("Decision Tree Accuracy:", round(dt_accuracy * 100, 2), "%")
# Out:
# Decision Tree Accuracy: 56.36 %

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVC

params = {
    "C": [0.1, 0.5, 1, 2, 5, 10]
}

grid = GridSearchCV(
    LinearSVC(),
    params,
    cv=2,
    scoring="accuracy"
)

grid.fit(X_train, y_train)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 5}
# 0.537037037037037

# %%
results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Linear SVM",
        "Naive Bayes",
        "Random Forest"
    ],
    "Accuracy": [
        lr_accuracy,
        svm_accuracy,
        nb_accuracy,
        rf_accuracy
    ]
})

print(results.sort_values("Accuracy", ascending=False))
# Out:
#                  Model  Accuracy
# 1           Linear SVM  0.690909
# 3        Random Forest  0.545455
# 0  Logistic Regression  0.490909
# 2          Naive Bayes  0.381818

# %%
import pickle

with open("../models/best_model.pkl", "wb") as file:
    pickle.dump(svm_model, file)

print("Best Model Saved Successfully")
# Out:
# Best Model Saved Successfully

# %%
import os

print(os.listdir("../models"))
# Out:
# ['best_model.pkl', 'label_encoder.pkl', 'tfidf_vectorizer.pkl', 'X_test.pkl', 'X_train.pkl', 'y_test.pkl', 'y_train.pkl']

# %%
import pickle

model = pickle.load(open("../models/best_model.pkl", "rb"))
vectorizer = pickle.load(open("../models/tfidf_vectorizer.pkl", "rb"))
label_encoder = pickle.load(open("../models/label_encoder.pkl", "rb"))

print(type(model))
print(type(vectorizer))
print(type(label_encoder))
# Out:
# <class 'sklearn.svm._classes.LinearSVC'>
# <class 'sklearn.feature_extraction.text.TfidfVectorizer'>
# <class 'sklearn.preprocessing._label.LabelEncoder'>

# %%
sample_resume = """
Python
Machine Learning
Deep Learning
TensorFlow
Scikit Learn
SQL
Power BI
Data Analysis
Pandas
NumPy
"""

sample_vector = vectorizer.transform([sample_resume])

prediction = model.predict(sample_vector)

role = label_encoder.inverse_transform(prediction)

print("Predicted Role:", role[0])
# Out:
# Predicted Role: Data Science & Analytics

# %%
sample_resume = """
HTML
CSS
JavaScript
React
Bootstrap
Tailwind CSS
Responsive Web Design
UI Development
"""

sample_vector = vectorizer.transform([sample_resume])

prediction = model.predict(sample_vector)

role = label_encoder.inverse_transform(prediction)

print(role[0])
# Out:
# Front-end Developer

# %%
print("Model Loaded Successfully")
print("Vectorizer Loaded Successfully")
print("Label Encoder Loaded Successfully")
print("Ready for FastAPI")
# Out:
# Model Loaded Successfully
# Vectorizer Loaded Successfully
# Label Encoder Loaded Successfully
# Ready for FastAPI
